# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\ogy87\anaconda3\envs\lion2\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
# ...

# %%
df_n = pd.read_csv('./gold_measurement_in_ready_N_top100.csv',encoding="utf-8-sig",)
df_y = pd.read_csv('gold_measurement_in_ready_Y_top100_verifiable',encoding="utf-8-sig",)
df_n.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4552/3688845110.py in <cell line: 0>()
# ----> 1 df_n = pd.read_csv('./gold_measurement_in_ready_N_top100.csv',encoding="utf-8-sig",)
#       2 df_y = pd.read_csv('gold_measurement_in_ready_Y_top100_verifiable',encoding="utf-8-sig",)
#       3 df_n.head(3)
#
# ...
